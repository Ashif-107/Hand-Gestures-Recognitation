# %%
import csv

import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split

RANDOM_SEED = 42

# %% [markdown]
# # 各パス指定

# %%
dataset = 'model/keypoint_classifier/keypoint.csv'
model_save_path = 'model/keypoint_classifier/keypoint_classifier.hdf5'

# %% [markdown]
# # 分類数設定

# %%
NUM_CLASSES = 5

# %% [markdown]
# # 学習データ読み込み

# %%
X_dataset = np.loadtxt(dataset, delimiter=',', dtype='float32', usecols=list(range(1, (21 * 2) + 1)))

# %%
y_dataset = np.loadtxt(dataset, delimiter=',', dtype='int32', usecols=(0))

# %%
X_train, X_test, y_train, y_test = train_test_split(X_dataset, y_dataset, train_size=0.75, random_state=RANDOM_SEED)

# %% [markdown]
# # モデル構築

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Input((21 * 2, )),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(20, activation='relu'),
    tf.keras.layers.Dropout(0.4),
    tf.keras.layers.Dense(10, activation='relu'),
    tf.keras.layers.Dense(NUM_CLASSES, activation='softmax')
])

# %%
model.summary()  # tf.keras.utils.plot_model(model, show_shapes=True)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dropout (Dropout)           (None, 42)                0
#
#  dense (Dense)               (None, 20)                860
#
#  dropout_1 (Dropout)         (None, 20)                0
#
#  dense_1 (Dense)             (None, 10)                210
#
#  dense_2 (Dense)             (None, 5)                 55
#
# =================================================================
# Total params: 1125 (4.39 KB)
# Trainable params: 1125 (4.39 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# モデルチェックポイントのコールバック
cp_callback = tf.keras.callbacks.ModelCheckpoint(
    model_save_path, verbose=1, save_weights_only=False)
# 早期打ち切り用コールバック
es_callback = tf.keras.callbacks.EarlyStopping(patience=20, verbose=1)

# %%
# モデルコンパイル
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %% [markdown]
# # モデル訓練

# %%
model.fit(
    X_train,
    y_train,
    epochs=1000,
    batch_size=128,
    validation_data=(X_test, y_test),
    callbacks=[cp_callback, es_callback]
)
# Out:
# Epoch 1/1000
# 23/30 [======================>.......] - ETA: 0s - loss: 1.5592 - accuracy: 0.2632
# Epoch 1: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 1s 11ms/step - loss: 1.5463 - accuracy: 0.2668 - val_loss: 1.4586 - val_accuracy: 0.2898
# Epoch 2/1000
# 26/30 [=========================>....] - ETA: 0s - loss: 1.4671 - accuracy: 0.3143
# Epoch 2: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 1.4621 - accuracy: 0.3162 - val_loss: 1.3952 - val_accuracy: 0.3961
# Epoch 3/1000
#  1/30 [>.............................] - ETA: 0s - loss: 1.4785 - accuracy: 0.3359
# C:\Users\Mohamed Ashif\AppData\Local\Programs\Python\Python38\lib\site-packages\keras\src\engine\training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 23/30 [======================>.......] - ETA: 0s - loss: 1.4213 - accuracy: 0.3526
# Epoch 3: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 1.4119 - accuracy: 0.3585 - val_loss: 1.3520 - val_accuracy: 0.3921
# Epoch 4/1000
# 24/30 [=======================>......] - ETA: 0s - loss: 1.3848 - accuracy: 0.3714
# Epoch 4: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 1.3759 - accuracy: 0.3826 - val_loss: 1.3210 - val_accuracy: 0.4449
# Epoch 5/1000
# 24/30 [=======================>......] - ETA: 0s - loss: 1.3432 - accuracy: 0.4105
# Epoch 5: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 1.3430 - accuracy: 0.4144 - val_loss: 1.2880 - val_accuracy: 0.4780
# Epoch 6/1000
# 25/30 [========================>.....] - ETA: 0s - loss: 1.3079 - accuracy: 0.4331
# Epoch 6: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 1.3024 - accuracy: 0.4336 - val_loss: 1.2449 - val_accuracy: 0.5213
# Epoch 7/1000
# 26/30 [=========================>....] - ETA: 0s - loss: 1.2731 - accuracy: 0.4615
# Epoch 7: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 1.2672 - accuracy: 0.4666 - val_loss: 1.1734 - val_accuracy: 0.5945
# Epoch 8/1000
# 26/30 [=========================>....] - ETA: 0s - loss: 1.2092 - accuracy: 0.4910
# Epoch 8: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 1.2096 - accuracy: 0.4934 - val_loss: 1.0812 - val_accuracy: 0.6787
# Epoch 9/1000
# 26/30 [=========================>....] - ETA: 0s - loss: 1.1658 - accuracy: 0.5114
# Epoch 9: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 1.1623 - accuracy: 0.5118 - val_loss: 0.9947 - val_accuracy: 0.6850
# Epoch 10/1000
# 27/30 [==========================>...] - ETA: 0s - loss: 1.1179 - accuracy: 0.5295
# Epoch 10: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 1.1222 - accuracy: 0.5244 - val_loss: 0.9275 - val_accuracy: 0.7346
# Epoch 11/1000
# 26/30 [=========================>....] - ETA: 0s - loss: 1.0844 - accuracy: 0.5535
# Epoch 11: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 1.0848 - accuracy: 0.5515 - val_loss: 0.8681 - val_accuracy: 0.7575
# Epoch 12/1000
# 26/30 [=========================>....] - ETA: 0s - loss: 1.0423 - accuracy: 0.5655
# Epoch 12: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 1.0353 - accuracy: 0.5667 - val_loss: 0.8213 - val_accuracy: 0.7787
# Epoch 13/1000
# 24/30 [=======================>......] - ETA: 0s - loss: 1.0081 - accuracy: 0.5908
# Epoch 13: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 1.0077 - accuracy: 0.5888 - val_loss: 0.7730 - val_accuracy: 0.7906
# Epoch 14/1000
# 21/30 [====================>.........] - ETA: 0s - loss: 0.9852 - accuracy: 0.5804
# Epoch 14: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.9827 - accuracy: 0.5840 - val_loss: 0.7345 - val_accuracy: 0.7984
# Epoch 15/1000
# 27/30 [==========================>...] - ETA: 0s - loss: 0.9700 - accuracy: 0.6056
# Epoch 15: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.9686 - accuracy: 0.6024 - val_loss: 0.7010 - val_accuracy: 0.8024
# Epoch 16/1000
# 28/30 [===========================>..] - ETA: 0s - loss: 0.9416 - accuracy: 0.6225
# Epoch 16: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.9385 - accuracy: 0.6242 - val_loss: 0.6810 - val_accuracy: 0.8252
# Epoch 17/1000
# 23/30 [======================>.......] - ETA: 0s - loss: 0.9335 - accuracy: 0.6145
# Epoch 17: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 5ms/step - loss: 0.9270 - accuracy: 0.6140 - val_loss: 0.6574 - val_accuracy: 0.8236
# Epoch 18/1000
# 21/30 [====================>.........] - ETA: 0s - loss: 0.8986 - accuracy: 0.6336
# Epoch 18: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.8987 - accuracy: 0.6318 - val_loss: 0.6362 - val_accuracy: 0.8480
# Epoch 19/1000
#  1/30 [>.............................] - ETA: 0s - loss: 0.8437 - accuracy: 0.6641
# Epoch 19: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.8902 - accuracy: 0.6379 - val_loss: 0.6154 - val_accuracy: 0.8551
# Epoch 20/1000
# 25/30 [========================>.....] - ETA: 0s - loss: 0.8866 - accuracy: 0.6322
# Epoch 20: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.8807 - accuracy: 0.6371 - val_loss: 0.5990 - val_accuracy: 0.8520
# Epoch 21/1000
# 24/30 [=======================>......] - ETA: 0s - loss: 0.8651 - accuracy: 0.6442
# Epoch 21: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.8653 - accuracy: 0.6436 - val_loss: 0.5830 - val_accuracy: 0.8646
# Epoch 22/1000
# 26/30 [=========================>....] - ETA: 0s - loss: 0.8796 - accuracy: 0.6442
# Epoch 22: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.8704 - accuracy: 0.6471 - val_loss: 0.5751 - val_accuracy: 0.8622
# Epoch 23/1000
# 22/30 [=====================>........] - ETA: 0s - loss: 0.8571 - accuracy: 0.6623
# Epoch 23: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.8627 - accuracy: 0.6560 - val_loss: 0.5582 - val_accuracy: 0.8795
# Epoch 24/1000
# 25/30 [========================>.....] - ETA: 0s - loss: 0.8225 - accuracy: 0.6700
# Epoch 24: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.8195 - accuracy: 0.6712 - val_loss: 0.5389 - val_accuracy: 0.8874
# Epoch 25/1000
# 25/30 [========================>.....] - ETA: 0s - loss: 0.8220 - accuracy: 0.6725
# Epoch 25: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.8150 - accuracy: 0.6752 - val_loss: 0.5254 - val_accuracy: 0.8882
# Epoch 26/1000
# 19/30 [==================>...........] - ETA: 0s - loss: 0.7952 - accuracy: 0.6785
# Epoch 26: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 5ms/step - loss: 0.8049 - accuracy: 0.6812 - val_loss: 0.5112 - val_accuracy: 0.8898
# Epoch 27/1000
# 29/30 [============================>.] - ETA: 0s - loss: 0.8072 - accuracy: 0.6862
# Epoch 27: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.8086 - accuracy: 0.6841 - val_loss: 0.5035 - val_accuracy: 0.8898
# Epoch 28/1000
# 24/30 [=======================>......] - ETA: 0s - loss: 0.7895 - accuracy: 0.6842
# Epoch 28: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.7977 - accuracy: 0.6825 - val_loss: 0.4982 - val_accuracy: 0.8984
# Epoch 29/1000
# 26/30 [=========================>....] - ETA: 0s - loss: 0.7855 - accuracy: 0.6899
# Epoch 29: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.7952 - accuracy: 0.6870 - val_loss: 0.4849 - val_accuracy: 0.9063
# Epoch 30/1000
# 27/30 [==========================>...] - ETA: 0s - loss: 0.7915 - accuracy: 0.6930
# Epoch 30: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.7874 - accuracy: 0.6941 - val_loss: 0.4800 - val_accuracy: 0.9126
# Epoch 31/1000
# 29/30 [============================>.] - ETA: 0s - loss: 0.7936 - accuracy: 0.6932
# Epoch 31: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.7958 - accuracy: 0.6912 - val_loss: 0.4784 - val_accuracy: 0.9024
# Epoch 32/1000
# 27/30 [==========================>...] - ETA: 0s - loss: 0.7612 - accuracy: 0.7028
# Epoch 32: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.7728 - accuracy: 0.6962 - val_loss: 0.4662 - val_accuracy: 0.9110
# Epoch 33/1000
# 25/30 [========================>.....] - ETA: 0s - loss: 0.7777 - accuracy: 0.7028
# Epoch 33: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.7681 - accuracy: 0.7025 - val_loss: 0.4562 - val_accuracy: 0.9110
# Epoch 34/1000
# 25/30 [========================>.....] - ETA: 0s - loss: 0.7856 - accuracy: 0.6959
# Epoch 34: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.7830 - accuracy: 0.6943 - val_loss: 0.4529 - val_accuracy: 0.9071
# Epoch 35/1000
# 25/30 [========================>.....] - ETA: 0s - loss: 0.7447 - accuracy: 0.7053
# Epoch 35: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.7574 - accuracy: 0.7038 - val_loss: 0.4408 - val_accuracy: 0.9157
# Epoch 36/1000
# 23/30 [======================>.......] - ETA: 0s - loss: 0.7711 - accuracy: 0.7079
# Epoch 36: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.7663 - accuracy: 0.7082 - val_loss: 0.4388 - val_accuracy: 0.9236
# Epoch 37/1000
# 25/30 [========================>.....] - ETA: 0s - loss: 0.7582 - accuracy: 0.6997
# Epoch 37: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.7468 - accuracy: 0.7051 - val_loss: 0.4334 - val_accuracy: 0.9189
# Epoch 38/1000
# 24/30 [=======================>......] - ETA: 0s - loss: 0.7561 - accuracy: 0.7122
# Epoch 38: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.7531 - accuracy: 0.7106 - val_loss: 0.4307 - val_accuracy: 0.9213
# Epoch 39/1000
# 18/30 [=================>............] - ETA: 0s - loss: 0.7453 - accuracy: 0.7036
# Epoch 39: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 5ms/step - loss: 0.7513 - accuracy: 0.7040 - val_loss: 0.4230 - val_accuracy: 0.9205
# Epoch 40/1000
# 25/30 [========================>.....] - ETA: 0s - loss: 0.7374 - accuracy: 0.7163
# Epoch 40: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 5ms/step - loss: 0.7393 - accuracy: 0.7169 - val_loss: 0.4159 - val_accuracy: 0.9157
# Epoch 41/1000
# 26/30 [=========================>....] - ETA: 0s - loss: 0.7255 - accuracy: 0.7218
# Epoch 41: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.7367 - accuracy: 0.7180 - val_loss: 0.4124 - val_accuracy: 0.9197
# Epoch 42/1000
# 27/30 [==========================>...] - ETA: 0s - loss: 0.7294 - accuracy: 0.7237
# Epoch 42: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.7275 - accuracy: 0.7227 - val_loss: 0.4046 - val_accuracy: 0.9142
# Epoch 43/1000
# 26/30 [=========================>....] - ETA: 0s - loss: 0.7384 - accuracy: 0.7172
# Epoch 43: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.7396 - accuracy: 0.7166 - val_loss: 0.4020 - val_accuracy: 0.9205
# Epoch 44/1000
# 26/30 [=========================>....] - ETA: 0s - loss: 0.7203 - accuracy: 0.7206
# Epoch 44: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.7341 - accuracy: 0.7198 - val_loss: 0.3996 - val_accuracy: 0.9252
# Epoch 45/1000
# 26/30 [=========================>....] - ETA: 0s - loss: 0.7089 - accuracy: 0.7284
# Epoch 45: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.7062 - accuracy: 0.7287 - val_loss: 0.3913 - val_accuracy: 0.9283
# Epoch 46/1000
# 27/30 [==========================>...] - ETA: 0s - loss: 0.7119 - accuracy: 0.7266
# Epoch 46: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.7092 - accuracy: 0.7279 - val_loss: 0.3887 - val_accuracy: 0.9268
# Epoch 47/1000
# 23/30 [======================>.......] - ETA: 0s - loss: 0.7103 - accuracy: 0.7289
# Epoch 47: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.7182 - accuracy: 0.7258 - val_loss: 0.3850 - val_accuracy: 0.9339
# Epoch 48/1000
# 28/30 [===========================>..] - ETA: 0s - loss: 0.7088 - accuracy: 0.7243
# Epoch 48: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.7121 - accuracy: 0.7235 - val_loss: 0.3848 - val_accuracy: 0.9236
# Epoch 49/1000
# 27/30 [==========================>...] - ETA: 0s - loss: 0.7271 - accuracy: 0.7199
# Epoch 49: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.7293 - accuracy: 0.7161 - val_loss: 0.3770 - val_accuracy: 0.9291
# Epoch 50/1000
# 24/30 [=======================>......] - ETA: 0s - loss: 0.6887 - accuracy: 0.7246
# Epoch 50: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.7076 - accuracy: 0.7182 - val_loss: 0.3737 - val_accuracy: 0.9362
# Epoch 51/1000
# 23/30 [======================>.......] - ETA: 0s - loss: 0.7103 - accuracy: 0.7337
# Epoch 51: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.6969 - accuracy: 0.7390 - val_loss: 0.3719 - val_accuracy: 0.9339
# Epoch 52/1000
# 23/30 [======================>.......] - ETA: 0s - loss: 0.7246 - accuracy: 0.7188
# Epoch 52: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.7136 - accuracy: 0.7274 - val_loss: 0.3681 - val_accuracy: 0.9378
# Epoch 53/1000
# 24/30 [=======================>......] - ETA: 0s - loss: 0.7157 - accuracy: 0.7272
# Epoch 53: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.7154 - accuracy: 0.7266 - val_loss: 0.3685 - val_accuracy: 0.9354
# Epoch 54/1000
# 25/30 [========================>.....] - ETA: 0s - loss: 0.6840 - accuracy: 0.7356
# Epoch 54: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.6867 - accuracy: 0.7335 - val_loss: 0.3627 - val_accuracy: 0.9346
# Epoch 55/1000
# 26/30 [=========================>....] - ETA: 0s - loss: 0.6936 - accuracy: 0.7359
# Epoch 55: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.6919 - accuracy: 0.7371 - val_loss: 0.3581 - val_accuracy: 0.9378
# Epoch 56/1000
# 21/30 [====================>.........] - ETA: 0s - loss: 0.7216 - accuracy: 0.7180
# Epoch 56: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.7164 - accuracy: 0.7216 - val_loss: 0.3606 - val_accuracy: 0.9331
# Epoch 57/1000
# 25/30 [========================>.....] - ETA: 0s - loss: 0.6680 - accuracy: 0.7584
# Epoch 57: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.6802 - accuracy: 0.7511 - val_loss: 0.3516 - val_accuracy: 0.9378
# Epoch 58/1000
# 24/30 [=======================>......] - ETA: 0s - loss: 0.6752 - accuracy: 0.7520
# Epoch 58: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.6838 - accuracy: 0.7458 - val_loss: 0.3522 - val_accuracy: 0.9378
# Epoch 59/1000
# 21/30 [====================>.........] - ETA: 0s - loss: 0.6905 - accuracy: 0.7422
# Epoch 59: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.6810 - accuracy: 0.7432 - val_loss: 0.3549 - val_accuracy: 0.9354
# Epoch 60/1000
# 24/30 [=======================>......] - ETA: 0s - loss: 0.6881 - accuracy: 0.7393
# Epoch 60: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.6864 - accuracy: 0.7377 - val_loss: 0.3426 - val_accuracy: 0.9370
# Epoch 61/1000
# 25/30 [========================>.....] - ETA: 0s - loss: 0.6868 - accuracy: 0.7406
# Epoch 61: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.6822 - accuracy: 0.7432 - val_loss: 0.3395 - val_accuracy: 0.9346
# Epoch 62/1000
# 27/30 [==========================>...] - ETA: 0s - loss: 0.6740 - accuracy: 0.7506
# Epoch 62: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.6758 - accuracy: 0.7489 - val_loss: 0.3340 - val_accuracy: 0.9370
# Epoch 63/1000
# 20/30 [===================>..........] - ETA: 0s - loss: 0.6608 - accuracy: 0.7453
# Epoch 63: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.6663 - accuracy: 0.7461 - val_loss: 0.3331 - val_accuracy: 0.9402
# Epoch 64/1000
# 24/30 [=======================>......] - ETA: 0s - loss: 0.6600 - accuracy: 0.7458
# Epoch 64: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.6619 - accuracy: 0.7447 - val_loss: 0.3320 - val_accuracy: 0.9425
# Epoch 65/1000
# 27/30 [==========================>...] - ETA: 0s - loss: 0.6575 - accuracy: 0.7552
# Epoch 65: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.6633 - accuracy: 0.7508 - val_loss: 0.3230 - val_accuracy: 0.9417
# Epoch 66/1000
# 25/30 [========================>.....] - ETA: 0s - loss: 0.6704 - accuracy: 0.7509
# Epoch 66: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.6691 - accuracy: 0.7511 - val_loss: 0.3295 - val_accuracy: 0.9465
# Epoch 67/1000
# 26/30 [=========================>....] - ETA: 0s - loss: 0.6666 - accuracy: 0.7404
# Epoch 67: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.6653 - accuracy: 0.7426 - val_loss: 0.3248 - val_accuracy: 0.9417
# Epoch 68/1000
# 28/30 [===========================>..] - ETA: 0s - loss: 0.6501 - accuracy: 0.7525
# Epoch 68: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.6525 - accuracy: 0.7542 - val_loss: 0.3213 - val_accuracy: 0.9409
# Epoch 69/1000
# 24/30 [=======================>......] - ETA: 0s - loss: 0.6702 - accuracy: 0.7458
# Epoch 69: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.6586 - accuracy: 0.7511 - val_loss: 0.3212 - val_accuracy: 0.9449
# Epoch 70/1000
# 28/30 [===========================>..] - ETA: 0s - loss: 0.6633 - accuracy: 0.7453
# Epoch 70: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.6638 - accuracy: 0.7458 - val_loss: 0.3205 - val_accuracy: 0.9433
# Epoch 71/1000
# 25/30 [========================>.....] - ETA: 0s - loss: 0.6494 - accuracy: 0.7603
# Epoch 71: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.6546 - accuracy: 0.7550 - val_loss: 0.3148 - val_accuracy: 0.9480
# Epoch 72/1000
# 26/30 [=========================>....] - ETA: 0s - loss: 0.6702 - accuracy: 0.7446
# Epoch 72: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.6679 - accuracy: 0.7455 - val_loss: 0.3182 - val_accuracy: 0.9441
# Epoch 73/1000
# 28/30 [===========================>..] - ETA: 0s - loss: 0.6588 - accuracy: 0.7520
# Epoch 73: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.6557 - accuracy: 0.7526 - val_loss: 0.3174 - val_accuracy: 0.9402
# Epoch 74/1000
# 26/30 [=========================>....] - ETA: 0s - loss: 0.6570 - accuracy: 0.7476
# Epoch 74: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.6583 - accuracy: 0.7487 - val_loss: 0.3086 - val_accuracy: 0.9488
# Epoch 75/1000
# 26/30 [=========================>....] - ETA: 0s - loss: 0.6585 - accuracy: 0.7626
# Epoch 75: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.6580 - accuracy: 0.7616 - val_loss: 0.3125 - val_accuracy: 0.9465
# Epoch 76/1000
# 24/30 [=======================>......] - ETA: 0s - loss: 0.6463 - accuracy: 0.7559
# Epoch 76: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.6426 - accuracy: 0.7550 - val_loss: 0.3072 - val_accuracy: 0.9457
# Epoch 77/1000
# 25/30 [========================>.....] - ETA: 0s - loss: 0.6674 - accuracy: 0.7553
# Epoch 77: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.6565 - accuracy: 0.7595 - val_loss: 0.3111 - val_accuracy: 0.9480
# Epoch 78/1000
# 24/30 [=======================>......] - ETA: 0s - loss: 0.6390 - accuracy: 0.7581
# Epoch 78: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.6378 - accuracy: 0.7579 - val_loss: 0.3030 - val_accuracy: 0.9488
# Epoch 79/1000
# 26/30 [=========================>....] - ETA: 0s - loss: 0.6526 - accuracy: 0.7518
# Epoch 79: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.6535 - accuracy: 0.7524 - val_loss: 0.3005 - val_accuracy: 0.9535
# Epoch 80/1000
# 19/30 [==================>...........] - ETA: 0s - loss: 0.6319 - accuracy: 0.7479
# Epoch 80: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 5ms/step - loss: 0.6364 - accuracy: 0.7524 - val_loss: 0.3033 - val_accuracy: 0.9465
# Epoch 81/1000
# 19/30 [==================>...........] - ETA: 0s - loss: 0.6471 - accuracy: 0.7603
# Epoch 81: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 5ms/step - loss: 0.6452 - accuracy: 0.7579 - val_loss: 0.3000 - val_accuracy: 0.9496
# Epoch 82/1000
# 17/30 [================>.............] - ETA: 0s - loss: 0.6437 - accuracy: 0.7546
# Epoch 82: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 5ms/step - loss: 0.6434 - accuracy: 0.7566 - val_loss: 0.2950 - val_accuracy: 0.9520
# Epoch 83/1000
# 22/30 [=====================>........] - ETA: 0s - loss: 0.6514 - accuracy: 0.7411
# Epoch 83: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.6541 - accuracy: 0.7421 - val_loss: 0.2951 - val_accuracy: 0.9496
# Epoch 84/1000
# 27/30 [==========================>...] - ETA: 0s - loss: 0.6216 - accuracy: 0.7685
# Epoch 84: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.6201 - accuracy: 0.7705 - val_loss: 0.2950 - val_accuracy: 0.9488
# Epoch 85/1000
# 23/30 [======================>.......] - ETA: 0s - loss: 0.6540 - accuracy: 0.7670
# Epoch 85: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.6465 - accuracy: 0.7673 - val_loss: 0.2921 - val_accuracy: 0.9504
# Epoch 86/1000
#  1/30 [>.............................] - ETA: 0s - loss: 0.5658 - accuracy: 0.8125
# Epoch 86: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.6289 - accuracy: 0.7676 - val_loss: 0.2877 - val_accuracy: 0.9520
# Epoch 87/1000
# 25/30 [========================>.....] - ETA: 0s - loss: 0.6472 - accuracy: 0.7597
# Epoch 87: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.6485 - accuracy: 0.7584 - val_loss: 0.2891 - val_accuracy: 0.9520
# Epoch 88/1000
# 24/30 [=======================>......] - ETA: 0s - loss: 0.6147 - accuracy: 0.7705
# Epoch 88: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.6225 - accuracy: 0.7718 - val_loss: 0.2886 - val_accuracy: 0.9543
# Epoch 89/1000
# 28/30 [===========================>..] - ETA: 0s - loss: 0.6508 - accuracy: 0.7620
# Epoch 89: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.6494 - accuracy: 0.7610 - val_loss: 0.2848 - val_accuracy: 0.9614
# Epoch 90/1000
# 24/30 [=======================>......] - ETA: 0s - loss: 0.6240 - accuracy: 0.7741
# Epoch 90: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.6226 - accuracy: 0.7718 - val_loss: 0.2908 - val_accuracy: 0.9457
# Epoch 91/1000
# 26/30 [=========================>....] - ETA: 0s - loss: 0.6365 - accuracy: 0.7629
# Epoch 91: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.6467 - accuracy: 0.7631 - val_loss: 0.2869 - val_accuracy: 0.9480
# Epoch 92/1000
# 26/30 [=========================>....] - ETA: 0s - loss: 0.6252 - accuracy: 0.7569
# Epoch 92: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.6329 - accuracy: 0.7566 - val_loss: 0.2864 - val_accuracy: 0.9496
# Epoch 93/1000
# 27/30 [==========================>...] - ETA: 0s - loss: 0.6065 - accuracy: 0.7729
# Epoch 93: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.6089 - accuracy: 0.7765 - val_loss: 0.2814 - val_accuracy: 0.9520
# Epoch 94/1000
# 27/30 [==========================>...] - ETA: 0s - loss: 0.6363 - accuracy: 0.7697
# Epoch 94: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.6367 - accuracy: 0.7707 - val_loss: 0.2831 - val_accuracy: 0.9551
# Epoch 95/1000
# 24/30 [=======================>......] - ETA: 0s - loss: 0.6310 - accuracy: 0.7581
# Epoch 95: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.6329 - accuracy: 0.7595 - val_loss: 0.2844 - val_accuracy: 0.9528
# Epoch 96/1000
# 26/30 [=========================>....] - ETA: 0s - loss: 0.6470 - accuracy: 0.7668
# Epoch 96: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.6450 - accuracy: 0.7710 - val_loss: 0.2816 - val_accuracy: 0.9551
# Epoch 97/1000
# 26/30 [=========================>....] - ETA: 0s - loss: 0.6298 - accuracy: 0.7617
# Epoch 97: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.6247 - accuracy: 0.7634 - val_loss: 0.2782 - val_accuracy: 0.9575
# Epoch 98/1000
# 26/30 [=========================>....] - ETA: 0s - loss: 0.6348 - accuracy: 0.7605
# Epoch 98: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.6337 - accuracy: 0.7610 - val_loss: 0.2838 - val_accuracy: 0.9528
# Epoch 99/1000
# 26/30 [=========================>....] - ETA: 0s - loss: 0.6335 - accuracy: 0.7650
# Epoch 99: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.6397 - accuracy: 0.7644 - val_loss: 0.2794 - val_accuracy: 0.9543
# Epoch 100/1000
# 26/30 [=========================>....] - ETA: 0s - loss: 0.6220 - accuracy: 0.7713
# Epoch 100: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.6182 - accuracy: 0.7726 - val_loss: 0.2845 - val_accuracy: 0.9504
# Epoch 101/1000
# 25/30 [========================>.....] - ETA: 0s - loss: 0.6167 - accuracy: 0.7747
# Epoch 101: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.6262 - accuracy: 0.7692 - val_loss: 0.2738 - val_accuracy: 0.9583
# Epoch 102/1000
# 25/30 [========================>.....] - ETA: 0s - loss: 0.6176 - accuracy: 0.7672
# Epoch 102: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.6108 - accuracy: 0.7723 - val_loss: 0.2752 - val_accuracy: 0.9535
# Epoch 103/1000
# 26/30 [=========================>....] - ETA: 0s - loss: 0.6272 - accuracy: 0.7668
# Epoch 103: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.6250 - accuracy: 0.7644 - val_loss: 0.2763 - val_accuracy: 0.9528
# Epoch 104/1000
# 26/30 [=========================>....] - ETA: 0s - loss: 0.6157 - accuracy: 0.7788
# Epoch 104: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.6121 - accuracy: 0.7791 - val_loss: 0.2730 - val_accuracy: 0.9559
# Epoch 105/1000
# 28/30 [===========================>..] - ETA: 0s - loss: 0.6000 - accuracy: 0.7815
# Epoch 105: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.5968 - accuracy: 0.7820 - val_loss: 0.2735 - val_accuracy: 0.9543
# Epoch 106/1000
# 25/30 [========================>.....] - ETA: 0s - loss: 0.6150 - accuracy: 0.7753
# Epoch 106: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.6129 - accuracy: 0.7805 - val_loss: 0.2656 - val_accuracy: 0.9614
# Epoch 107/1000
# 27/30 [==========================>...] - ETA: 0s - loss: 0.6165 - accuracy: 0.7665
# Epoch 107: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.6099 - accuracy: 0.7700 - val_loss: 0.2734 - val_accuracy: 0.9480
# Epoch 108/1000
# 27/30 [==========================>...] - ETA: 0s - loss: 0.5824 - accuracy: 0.7891
# Epoch 108: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.5778 - accuracy: 0.7918 - val_loss: 0.2594 - val_accuracy: 0.9606
# Epoch 109/1000
# 19/30 [==================>...........] - ETA: 0s - loss: 0.6259 - accuracy: 0.7693
# Epoch 109: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 5ms/step - loss: 0.6211 - accuracy: 0.7676 - val_loss: 0.2649 - val_accuracy: 0.9583
# Epoch 110/1000
# 23/30 [======================>.......] - ETA: 0s - loss: 0.6201 - accuracy: 0.7663
# Epoch 110: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.6223 - accuracy: 0.7676 - val_loss: 0.2684 - val_accuracy: 0.9575
# Epoch 111/1000
# 24/30 [=======================>......] - ETA: 0s - loss: 0.6076 - accuracy: 0.7734
# Epoch 111: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.6060 - accuracy: 0.7752 - val_loss: 0.2712 - val_accuracy: 0.9591
# Epoch 112/1000
# 22/30 [=====================>........] - ETA: 0s - loss: 0.6298 - accuracy: 0.7699
# Epoch 112: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.6137 - accuracy: 0.7742 - val_loss: 0.2659 - val_accuracy: 0.9567
# Epoch 113/1000
# 23/30 [======================>.......] - ETA: 0s - loss: 0.6165 - accuracy: 0.7632
# Epoch 113: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 5ms/step - loss: 0.6210 - accuracy: 0.7610 - val_loss: 0.2673 - val_accuracy: 0.9567
# Epoch 114/1000
# 25/30 [========================>.....] - ETA: 0s - loss: 0.6121 - accuracy: 0.7672
# Epoch 114: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 5ms/step - loss: 0.6172 - accuracy: 0.7660 - val_loss: 0.2687 - val_accuracy: 0.9559
# Epoch 115/1000
# 19/30 [==================>...........] - ETA: 0s - loss: 0.6161 - accuracy: 0.7701
# Epoch 115: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.6091 - accuracy: 0.7747 - val_loss: 0.2663 - val_accuracy: 0.9559
# Epoch 116/1000
# 28/30 [===========================>..] - ETA: 0s - loss: 0.6185 - accuracy: 0.7673
# Epoch 116: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.6168 - accuracy: 0.7689 - val_loss: 0.2712 - val_accuracy: 0.9567
# Epoch 117/1000
# 27/30 [==========================>...] - ETA: 0s - loss: 0.5981 - accuracy: 0.7766
# Epoch 117: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.5943 - accuracy: 0.7768 - val_loss: 0.2679 - val_accuracy: 0.9512
# Epoch 118/1000
# 19/30 [==================>...........] - ETA: 0s - loss: 0.5838 - accuracy: 0.7866
# Epoch 118: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.5979 - accuracy: 0.7789 - val_loss: 0.2615 - val_accuracy: 0.9551
# Epoch 119/1000
# 26/30 [=========================>....] - ETA: 0s - loss: 0.5954 - accuracy: 0.7809
# Epoch 119: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.5917 - accuracy: 0.7831 - val_loss: 0.2575 - val_accuracy: 0.9591
# Epoch 120/1000
# 30/30 [==============================] - ETA: 0s - loss: 0.5899 - accuracy: 0.7812
# Epoch 120: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 3ms/step - loss: 0.5899 - accuracy: 0.7812 - val_loss: 0.2572 - val_accuracy: 0.9598
# Epoch 121/1000
# 27/30 [==========================>...] - ETA: 0s - loss: 0.5975 - accuracy: 0.7804
# Epoch 121: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.5987 - accuracy: 0.7770 - val_loss: 0.2611 - val_accuracy: 0.9591
# Epoch 122/1000
# 24/30 [=======================>......] - ETA: 0s - loss: 0.5933 - accuracy: 0.7786
# Epoch 122: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.5918 - accuracy: 0.7786 - val_loss: 0.2587 - val_accuracy: 0.9591
# Epoch 123/1000
# 20/30 [===================>..........] - ETA: 0s - loss: 0.5887 - accuracy: 0.7762
# Epoch 123: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.5844 - accuracy: 0.7763 - val_loss: 0.2596 - val_accuracy: 0.9551
# Epoch 124/1000
# 20/30 [===================>..........] - ETA: 0s - loss: 0.5941 - accuracy: 0.7730
# Epoch 124: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 5ms/step - loss: 0.5977 - accuracy: 0.7768 - val_loss: 0.2607 - val_accuracy: 0.9575
# Epoch 125/1000
# 23/30 [======================>.......] - ETA: 0s - loss: 0.5747 - accuracy: 0.7816
# Epoch 125: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.5924 - accuracy: 0.7760 - val_loss: 0.2699 - val_accuracy: 0.9575
# Epoch 126/1000
# 25/30 [========================>.....] - ETA: 0s - loss: 0.5832 - accuracy: 0.7834
# Epoch 126: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.5912 - accuracy: 0.7818 - val_loss: 0.2605 - val_accuracy: 0.9591
# Epoch 127/1000
# 23/30 [======================>.......] - ETA: 0s - loss: 0.5833 - accuracy: 0.7887
# Epoch 127: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.5942 - accuracy: 0.7852 - val_loss: 0.2630 - val_accuracy: 0.9551
# Epoch 128/1000
# 23/30 [======================>.......] - ETA: 0s - loss: 0.5910 - accuracy: 0.7884
# Epoch 128: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.5994 - accuracy: 0.7841 - val_loss: 0.2631 - val_accuracy: 0.9575
# Epoch 129/1000
# 26/30 [=========================>....] - ETA: 0s - loss: 0.6008 - accuracy: 0.7806
# Epoch 129: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.5893 - accuracy: 0.7847 - val_loss: 0.2538 - val_accuracy: 0.9638
# Epoch 130/1000
# 25/30 [========================>.....] - ETA: 0s - loss: 0.6024 - accuracy: 0.7781
# Epoch 130: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.6032 - accuracy: 0.7763 - val_loss: 0.2545 - val_accuracy: 0.9559
# Epoch 131/1000
# 27/30 [==========================>...] - ETA: 0s - loss: 0.5793 - accuracy: 0.7862
# Epoch 131: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.5874 - accuracy: 0.7839 - val_loss: 0.2586 - val_accuracy: 0.9520
# Epoch 132/1000
# 26/30 [=========================>....] - ETA: 0s - loss: 0.5607 - accuracy: 0.7888
# Epoch 132: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.5614 - accuracy: 0.7881 - val_loss: 0.2497 - val_accuracy: 0.9551
# Epoch 133/1000
# 20/30 [===================>..........] - ETA: 0s - loss: 0.5889 - accuracy: 0.7895
# Epoch 133: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 5ms/step - loss: 0.5883 - accuracy: 0.7894 - val_loss: 0.2562 - val_accuracy: 0.9504
# Epoch 134/1000
# 24/30 [=======================>......] - ETA: 0s - loss: 0.5801 - accuracy: 0.7871
# Epoch 134: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.5753 - accuracy: 0.7860 - val_loss: 0.2473 - val_accuracy: 0.9575
# Epoch 135/1000
# 25/30 [========================>.....] - ETA: 0s - loss: 0.5980 - accuracy: 0.7797
# Epoch 135: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.5926 - accuracy: 0.7820 - val_loss: 0.2530 - val_accuracy: 0.9583
# Epoch 136/1000
# 24/30 [=======================>......] - ETA: 0s - loss: 0.6121 - accuracy: 0.7780
# Epoch 136: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.6071 - accuracy: 0.7773 - val_loss: 0.2484 - val_accuracy: 0.9614
# Epoch 137/1000
# 24/30 [=======================>......] - ETA: 0s - loss: 0.5762 - accuracy: 0.7887
# Epoch 137: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.5772 - accuracy: 0.7878 - val_loss: 0.2599 - val_accuracy: 0.9496
# Epoch 138/1000
# 23/30 [======================>.......] - ETA: 0s - loss: 0.5486 - accuracy: 0.7959
# Epoch 138: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.5582 - accuracy: 0.7912 - val_loss: 0.2539 - val_accuracy: 0.9575
# Epoch 139/1000
# 26/30 [=========================>....] - ETA: 0s - loss: 0.6156 - accuracy: 0.7791
# Epoch 139: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.6014 - accuracy: 0.7855 - val_loss: 0.2556 - val_accuracy: 0.9551
# Epoch 140/1000
# 26/30 [=========================>....] - ETA: 0s - loss: 0.5761 - accuracy: 0.7891
# Epoch 140: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.5739 - accuracy: 0.7891 - val_loss: 0.2526 - val_accuracy: 0.9583
# Epoch 141/1000
# 26/30 [=========================>....] - ETA: 0s - loss: 0.5815 - accuracy: 0.7776
# Epoch 141: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.5771 - accuracy: 0.7799 - val_loss: 0.2485 - val_accuracy: 0.9646
# Epoch 142/1000
# 24/30 [=======================>......] - ETA: 0s - loss: 0.5460 - accuracy: 0.8034
# Epoch 142: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.5492 - accuracy: 0.7973 - val_loss: 0.2427 - val_accuracy: 0.9685
# Epoch 143/1000
# 27/30 [==========================>...] - ETA: 0s - loss: 0.5794 - accuracy: 0.7873
# Epoch 143: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.5876 - accuracy: 0.7828 - val_loss: 0.2536 - val_accuracy: 0.9591
# Epoch 144/1000
# 24/30 [=======================>......] - ETA: 0s - loss: 0.5684 - accuracy: 0.7910
# Epoch 144: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.5696 - accuracy: 0.7910 - val_loss: 0.2468 - val_accuracy: 0.9614
# Epoch 145/1000
# 23/30 [======================>.......] - ETA: 0s - loss: 0.5885 - accuracy: 0.7843
# Epoch 145: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.5790 - accuracy: 0.7897 - val_loss: 0.2539 - val_accuracy: 0.9504
# Epoch 146/1000
# 23/30 [======================>.......] - ETA: 0s - loss: 0.5877 - accuracy: 0.7850
# Epoch 146: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 5ms/step - loss: 0.5901 - accuracy: 0.7844 - val_loss: 0.2524 - val_accuracy: 0.9551
# Epoch 147/1000
# 24/30 [=======================>......] - ETA: 0s - loss: 0.5680 - accuracy: 0.7956
# Epoch 147: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.5672 - accuracy: 0.7946 - val_loss: 0.2447 - val_accuracy: 0.9638
# Epoch 148/1000
# 25/30 [========================>.....] - ETA: 0s - loss: 0.5830 - accuracy: 0.7822
# Epoch 148: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.5769 - accuracy: 0.7862 - val_loss: 0.2525 - val_accuracy: 0.9551
# Epoch 149/1000
# 26/30 [=========================>....] - ETA: 0s - loss: 0.5852 - accuracy: 0.7855
# Epoch 149: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.5867 - accuracy: 0.7865 - val_loss: 0.2481 - val_accuracy: 0.9575
# Epoch 150/1000
# 26/30 [=========================>....] - ETA: 0s - loss: 0.5913 - accuracy: 0.7882
# Epoch 150: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.5841 - accuracy: 0.7910 - val_loss: 0.2543 - val_accuracy: 0.9528
# Epoch 151/1000
# 24/30 [=======================>......] - ETA: 0s - loss: 0.5655 - accuracy: 0.7923
# Epoch 151: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.5664 - accuracy: 0.7889 - val_loss: 0.2448 - val_accuracy: 0.9598
# Epoch 152/1000
# 27/30 [==========================>...] - ETA: 0s - loss: 0.5835 - accuracy: 0.7841
# Epoch 152: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.5909 - accuracy: 0.7805 - val_loss: 0.2510 - val_accuracy: 0.9575
# Epoch 153/1000
# 26/30 [=========================>....] - ETA: 0s - loss: 0.5778 - accuracy: 0.7843
# Epoch 153: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.5687 - accuracy: 0.7889 - val_loss: 0.2556 - val_accuracy: 0.9551
# Epoch 154/1000
# 24/30 [=======================>......] - ETA: 0s - loss: 0.5586 - accuracy: 0.7933
# Epoch 154: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.5590 - accuracy: 0.7954 - val_loss: 0.2466 - val_accuracy: 0.9591
# Epoch 155/1000
# 20/30 [===================>..........] - ETA: 0s - loss: 0.5729 - accuracy: 0.7941
# Epoch 155: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 5ms/step - loss: 0.5574 - accuracy: 0.7973 - val_loss: 0.2514 - val_accuracy: 0.9543
# Epoch 156/1000
# 24/30 [=======================>......] - ETA: 0s - loss: 0.5767 - accuracy: 0.7822
# Epoch 156: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.5673 - accuracy: 0.7849 - val_loss: 0.2461 - val_accuracy: 0.9551
# Epoch 157/1000
# 27/30 [==========================>...] - ETA: 0s - loss: 0.5585 - accuracy: 0.7980
# Epoch 157: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.5595 - accuracy: 0.7962 - val_loss: 0.2483 - val_accuracy: 0.9575
# Epoch 158/1000
# 24/30 [=======================>......] - ETA: 0s - loss: 0.5648 - accuracy: 0.7969
# Epoch 158: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 5ms/step - loss: 0.5713 - accuracy: 0.7918 - val_loss: 0.2446 - val_accuracy: 0.9614
# Epoch 159/1000
# 23/30 [======================>.......] - ETA: 0s - loss: 0.5532 - accuracy: 0.7955
# Epoch 159: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 5ms/step - loss: 0.5630 - accuracy: 0.7889 - val_loss: 0.2460 - val_accuracy: 0.9535
# Epoch 160/1000
# 25/30 [========================>.....] - ETA: 0s - loss: 0.5641 - accuracy: 0.8016
# Epoch 160: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 5ms/step - loss: 0.5704 - accuracy: 0.7986 - val_loss: 0.2449 - val_accuracy: 0.9528
# Epoch 161/1000
# 21/30 [====================>.........] - ETA: 0s - loss: 0.5725 - accuracy: 0.7835
# Epoch 161: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.5644 - accuracy: 0.7907 - val_loss: 0.2531 - val_accuracy: 0.9488
# Epoch 162/1000
# 22/30 [=====================>........] - ETA: 0s - loss: 0.5548 - accuracy: 0.8036
# Epoch 162: saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.5621 - accuracy: 0.7988 - val_loss: 0.2477 - val_accuracy: 0.9583
# Epoch 162: early stopping

# %%
# モデル評価
val_loss, val_acc = model.evaluate(X_test, y_test, batch_size=128)
# Out:
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2477 - accuracy: 0.9583

# %%
# 保存したモデルのロード
model = tf.keras.models.load_model(model_save_path)

# %%
# 推論テスト
predict_result = model.predict(np.array([X_test[0]]))
print(np.squeeze(predict_result))
print(np.argmax(np.squeeze(predict_result)))
# Out:
# 1/1 [==============================] - 0s 115ms/step
# [1.5545674e-02 9.4000715e-01 4.4182889e-02 2.6064095e-09 2.6419552e-04]
# 1

# %% [markdown]
# # 混同行列

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report

def print_confusion_matrix(y_true, y_pred, report=True):
    labels = sorted(list(set(y_true)))
    cmx_data = confusion_matrix(y_true, y_pred, labels=labels)
    
    df_cmx = pd.DataFrame(cmx_data, index=labels, columns=labels)
 
    fig, ax = plt.subplots(figsize=(7, 6))
    sns.heatmap(df_cmx, annot=True, fmt='g' ,square=False)
    ax.set_ylim(len(set(y_true)), 0)
    plt.show()
    
    if report:
        print('Classification Report')
        print(classification_report(y_test, y_pred))

Y_pred = model.predict(X_test)
y_pred = np.argmax(Y_pred, axis=1)

print_confusion_matrix(y_test, y_pred)
# Out:
# 40/40 [==============================] - 0s 2ms/step
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.97       396
#            1       0.99      0.93      0.96       382
#            2       0.91      0.99      0.94       328
#            3       0.97      0.99      0.98        94
#            4       1.00      0.79      0.88        70
#
#     accuracy                           0.96      1270
#    macro avg       0.97      0.94      0.95      1270
# weighted avg       0.96      0.96      0.96      1270

# %% [markdown]
# # Tensorflow-Lite用のモデルへ変換

# %%
# 推論専用のモデルとして保存
model.save(model_save_path, include_optimizer=False)
# Out:
# C:\Users\Mohamed Ashif\AppData\Local\Programs\Python\Python38\lib\site-packages\keras\src\engine\training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
# モデルを変換(量子化)
tflite_save_path = 'model/keypoint_classifier/keypoint_classifier.tflite'

converter = tf.lite.TFLiteConverter.from_keras_model(model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
tflite_quantized_model = converter.convert()

open(tflite_save_path, 'wb').write(tflite_quantized_model)
# Out:
# INFO:tensorflow:Assets written to: C:\Users\MOHAME~1\AppData\Local\Temp\tmptcytbf6r\assets
# INFO:tensorflow:Assets written to: C:\Users\MOHAME~1\AppData\Local\Temp\tmptcytbf6r\assets
# 6588

# %% [markdown]
# # 推論テスト

# %%
interpreter = tf.lite.Interpreter(model_path=tflite_save_path)
interpreter.allocate_tensors()

# %%
# 入出力テンソルを取得
input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()

# %%
interpreter.set_tensor(input_details[0]['index'], np.array([X_test[0]]))

# %%
# %%time
# 推論実施
interpreter.invoke()
tflite_results = interpreter.get_tensor(output_details[0]['index'])
# Out:
# CPU times: total: 0 ns
# Wall time: 0 ns

# %%
print(np.squeeze(tflite_results))
print(np.argmax(np.squeeze(tflite_results)))
# Out:
# [1.5545660e-02 9.4000727e-01 4.4182856e-02 2.6064002e-09 2.6419453e-04]
# 1
